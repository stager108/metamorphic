# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
for i in range(0, 5):
    data = pd.DataFrame(pd.read_csv('results/test3i/genome_mut_i'+str(i) + '_seq.txt', sep='\t'))
    plt.figure(figsize=(10, 3))
    plt.plot(data['position'], data['depth.ratio'])
    plt.show()

# %%
#! pip install pyvcf

# %%
import vcf
plt.figure(figsize=(10, 3))
for i in range(4, -1, -1):
    vcf_reader = vcf.Reader(open('results/test3i/test3i0'+str(i) + '.vcf', 'r'))
    for record in vcf_reader:
        plt.scatter(record.POS, i, color='blue')
  #      print(record.POS, i)
  #      print(record)
   # print()
plt.show()
